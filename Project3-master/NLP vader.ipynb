# %%
# import pandas, nltk, and vader
import nltk
import pandas as pd
import os
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %%
# load tweets into a dataframe
df = pd.read_json(os.path.join('condensed_2018.json'))

# %%
df.head()
# Out:
#            created_at  favorite_count               id_str  \
# 0 2018-12-31 23:53:06          136012  1079888205351145472
# 1 2018-12-31 20:02:52           65069  1079830268708556800
# 2 2018-12-31 20:02:52           76721  1079830267274108928
# 3 2018-12-31 15:39:15          127485  1079763923845419008
# 4 2018-12-31 15:37:14          132439  1079763419908243456
#
#    in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 0                      NaN       False          33548  Twitter for iPhone
# 1               25073877.0       False          17456  Twitter for iPhone
# 2                      NaN       False          21030  Twitter for iPhone
# 3                      NaN       False          29610  Twitter for iPhone
# 4                      NaN       False          30957  Twitter for iPhone
#
#                                                 text
# 0            HAPPY NEW YEAR! https://t.co/bHoPDPQ7G6
# 1  ....Senator Schumer, more than a year longer t...
# 2  Heads of countries are calling wanting to know...
# 3  It’s incredible how Democrats can all use thei...
# 4  I’m in the Oval Office. Democrats, come back f...

# %%
# drop retweets
dfRt = df[~df.text.str.startswith('RT')]

# %%
dfRt.head()
# Out:
#            created_at  favorite_count               id_str  \
# 0 2018-12-31 23:53:06          136012  1079888205351145472
# 1 2018-12-31 20:02:52           65069  1079830268708556800
# 2 2018-12-31 20:02:52           76721  1079830267274108928
# 3 2018-12-31 15:39:15          127485  1079763923845419008
# 4 2018-12-31 15:37:14          132439  1079763419908243456
#
#    in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 0                      NaN       False          33548  Twitter for iPhone
# 1               25073877.0       False          17456  Twitter for iPhone
# 2                      NaN       False          21030  Twitter for iPhone
# 3                      NaN       False          29610  Twitter for iPhone
# 4                      NaN       False          30957  Twitter for iPhone
#
#                                                 text
# 0            HAPPY NEW YEAR! https://t.co/bHoPDPQ7G6
# 1  ....Senator Schumer, more than a year longer t...
# 2  Heads of countries are calling wanting to know...
# 3  It’s incredible how Democrats can all use thei...
# 4  I’m in the Oval Office. Democrats, come back f...

# %%
dfRt['created_at'] = pd.to_datetime(dfRt['created_at'])

dfRt['day_of_week'] = dfRt['created_at'].dt.day_name()
dfRt.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#            created_at  favorite_count               id_str  \
# 0 2018-12-31 23:53:06          136012  1079888205351145472
# 1 2018-12-31 20:02:52           65069  1079830268708556800
# 2 2018-12-31 20:02:52           76721  1079830267274108928
# 3 2018-12-31 15:39:15          127485  1079763923845419008
# 4 2018-12-31 15:37:14          132439  1079763419908243456
#
#    in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 0                      NaN       False          33548  Twitter for iPhone
# 1               25073877.0       False          17456  Twitter for iPhone
# 2                      NaN       False          21030  Twitter for iPhone
# 3                      NaN       False          29610  Twitter for iPhone
# 4                      NaN       False          30957  Twitter for iPhone
#
#                                                 text day_of_week
# 0            HAPPY NEW YEAR! https://t.co/bHoPDPQ7G6      Monday
# 1  ....Senator Schumer, more than a year longer t...      Monday
# 2  Heads of countries are calling wanting to know...      Monday
# 3  It’s incredible how Democrats can all use thei...      Monday
# 4  I’m in the Oval Office. Democrats, come back f...      Monday

# %%
#dfRt.to_csv('cleaneda2018.csv',index=False)

# %%
# load tweets into a dataframe
df2 = pd.read_json(os.path.join('condensed_2017.json'))

# %%
frames = [df, df2]

# %%
result = pd.concat(frames)
# Reset index
df3 = result.reset_index(drop=True)
df3.head()
# Out:
#            created_at  favorite_count               id_str  \
# 0 2018-12-31 23:53:06          136012  1079888205351145472
# 1 2018-12-31 20:02:52           65069  1079830268708556800
# 2 2018-12-31 20:02:52           76721  1079830267274108928
# 3 2018-12-31 15:39:15          127485  1079763923845419008
# 4 2018-12-31 15:37:14          132439  1079763419908243456
#
#    in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 0                      NaN       False          33548  Twitter for iPhone
# 1               25073877.0       False          17456  Twitter for iPhone
# 2                      NaN       False          21030  Twitter for iPhone
# 3                      NaN       False          29610  Twitter for iPhone
# 4                      NaN       False          30957  Twitter for iPhone
#
#                                                 text
# 0            HAPPY NEW YEAR! https://t.co/bHoPDPQ7G6
# 1  ....Senator Schumer, more than a year longer t...
# 2  Heads of countries are calling wanting to know...
# 3  It’s incredible how Democrats can all use thei...
# 4  I’m in the Oval Office. Democrats, come back f...

# %%
# drop retweets
dfRt3 = df3[~df3.text.str.startswith('RT')]
dfRt3.head()
# Out:
#            created_at  favorite_count               id_str  \
# 0 2018-12-31 23:53:06          136012  1079888205351145472
# 1 2018-12-31 20:02:52           65069  1079830268708556800
# 2 2018-12-31 20:02:52           76721  1079830267274108928
# 3 2018-12-31 15:39:15          127485  1079763923845419008
# 4 2018-12-31 15:37:14          132439  1079763419908243456
#
#    in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 0                      NaN       False          33548  Twitter for iPhone
# 1               25073877.0       False          17456  Twitter for iPhone
# 2                      NaN       False          21030  Twitter for iPhone
# 3                      NaN       False          29610  Twitter for iPhone
# 4                      NaN       False          30957  Twitter for iPhone
#
#                                                 text
# 0            HAPPY NEW YEAR! https://t.co/bHoPDPQ7G6
# 1  ....Senator Schumer, more than a year longer t...
# 2  Heads of countries are calling wanting to know...
# 3  It’s incredible how Democrats can all use thei...
# 4  I’m in the Oval Office. Democrats, come back f...

# %%
dfRt3['created_at'] = pd.to_datetime(dfRt3['created_at'])

dfRt3['day_of_week'] = dfRt3['created_at'].dt.day_name()
dfRt3.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#            created_at  favorite_count               id_str  \
# 0 2018-12-31 23:53:06          136012  1079888205351145472
# 1 2018-12-31 20:02:52           65069  1079830268708556800
# 2 2018-12-31 20:02:52           76721  1079830267274108928
# 3 2018-12-31 15:39:15          127485  1079763923845419008
# 4 2018-12-31 15:37:14          132439  1079763419908243456
#
#    in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 0                      NaN       False          33548  Twitter for iPhone
# 1               25073877.0       False          17456  Twitter for iPhone
# 2                      NaN       False          21030  Twitter for iPhone
# 3                      NaN       False          29610  Twitter for iPhone
# 4                      NaN       False          30957  Twitter for iPhone
#
#                                                 text day_of_week
# 0            HAPPY NEW YEAR! https://t.co/bHoPDPQ7G6      Monday
# 1  ....Senator Schumer, more than a year longer t...      Monday
# 2  Heads of countries are calling wanting to know...      Monday
# 3  It’s incredible how Democrats can all use thei...      Monday
# 4  I’m in the Oval Office. Democrats, come back f...      Monday

# %%
dfRt3.to_csv('cleaneda2017_2018.csv',index=False)

# %%
Monday_df=dfRt.loc[dfRt['day_of_week'] == "Monday"]
Monday_df.head()
# Out:
#            created_at  favorite_count               id_str  \
# 0 2018-12-31 23:53:06          136012  1079888205351145472
# 1 2018-12-31 20:02:52           65069  1079830268708556800
# 2 2018-12-31 20:02:52           76721  1079830267274108928
# 3 2018-12-31 15:39:15          127485  1079763923845419008
# 4 2018-12-31 15:37:14          132439  1079763419908243456
#
#    in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 0                      NaN       False          33548  Twitter for iPhone
# 1               25073877.0       False          17456  Twitter for iPhone
# 2                      NaN       False          21030  Twitter for iPhone
# 3                      NaN       False          29610  Twitter for iPhone
# 4                      NaN       False          30957  Twitter for iPhone
#
#                                                 text day_of_week
# 0            HAPPY NEW YEAR! https://t.co/bHoPDPQ7G6      Monday
# 1  ....Senator Schumer, more than a year longer t...      Monday
# 2  Heads of countries are calling wanting to know...      Monday
# 3  It’s incredible how Democrats can all use thei...      Monday
# 4  I’m in the Oval Office. Democrats, come back f...      Monday

# %%
# setting text column to a varible
sentences = Monday_df["text"]

# %%
type(sentences)
# Out:
# pandas.core.series.Series

# %%
sentences = sentences.to_string()

# %%
# tokenize text column
from nltk import tokenize
sentences = tokenize.sent_tokenize(sentences)

# %%
sid = SentimentIntensityAnalyzer()

# %%
#MONDAYS 2018
vScore = []
for sentence in sentences:
#     print(sentence)
    ss = sid.polarity_scores(sentence)
#     tCompScores['sentimentScores'] = dfRt['id_str'].map(ss.get('compound'))
#     tCompScores.head()
    score = (ss.get("compound"))
#     how is k working here? How does this format in this manner?
#     for k in sorted(ss):
#         print('{0}: {1}, '.format(k, ss[k]), end='')
#         print()
    print (ss)
# Out:
# {'neg': 0.0, 'neu': 0.334, 'pos': 0.666, 'compound': 0.6114}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.043, 'neu': 0.88, 'pos': 0.077, 'compound': 0.5647}
# {'neg': 0.0, 'neu': 0.548, 'pos': 0.452, 'compound': 0.628}
# {'neg': 0.0, 'neu': 0.887, 'pos': 0.113, 'compound': 0.7269}
# {'neg': 0.038, 'neu': 0.851, 'pos': 0.111, 'compound': 0.96}
# {'neg': 0.0, 'neu': 0.897, 'pos': 0.103, 'compound': 0.7845}
# {'neg': 0.165, 'neu': 0.835, 'pos': 0.0, 'compound': -0.6908}
# {'neg': 0.079, 'neu': 0.78, 'pos': 0.141, 'compound': 0.8313}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.094, 'neu': 0.821, 'pos': 0.085, 'compound': -0.1796}
# {'neg': 0.134, 'neu': 0.746, 'pos': 0.12, 'compound': -0.2714}
# {'neg': 0.0, 'neu': 0.686, 'pos': 0.314, 'compound': 0.8087}
# {'neg': 0.192, 'neu': 0.808, 'pos': 0.0, 'compound': -0.8819}
# {'neg': 0.045, 'neu': 0.849, 'pos': 0.106, 'compound': 0.5859}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'compound': 0.765}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.4939}
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0
# 134 2018-12-18 22:42:37           45671  1075159426968027136
# 137 2018-12-18 13:32:34           82019  1075021002441220096
# 138 2018-12-18 13:22:29           75842  1075018465356996608
#
#      in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 42                       NaN       False          46597  Twitter for iPhone
# 43                       NaN       False          89255  Twitter for iPhone
# 134                      NaN       False          10816  Twitter for iPhone
# 137                      NaN       False          21238  Twitter for iPhone
# 138                      NaN       False          19460  Twitter for iPhone
#
#                                                   text day_of_week
# 42   I hope everyone, even the Fake News Media, is ...     Tuesday
# 43                                    Merry Christmas!     Tuesday
# 134  “President Donald J. Trump’s Commission on Sch...     Tuesday
# 137  Michael Isikoff was the first to report Dossie...     Tuesday
# 138  ....WILL NEVER BE PROVEN AND ARE LIKELY FALSE....     Tuesday

# %%
# setting text column to a varible
sentences = Tuesday_df["text"]
sentences = sentences.to_string()
# tokenize text column
from nltk import tokenize
sentences = tokenize.sent_tokenize(sentences)
sid = SentimentIntensityAnalyzer()
#TUESDAYS 2018
vScore = []
for sentence in sentences:
#     print(sentence)
    ss = sid.polarity_scores(sentence)
#     tCompScores['sentimentScores'] = dfRt['id_str'].map(ss.get('compound'))
#     tCompScores.head()
    score = (ss.get("compound"))
#     how is k working here? How does this format in this manner?
#     for k in sorted(ss):
#         print('{0}: {1}, '.format(k, ss[k]), end='')
#         print()
    print (ss)
# Out:
# {'neg': 0.157, 'neu': 0.505, 'pos': 0.338, 'compound': 0.5562}
# {'neg': 0.135, 'neu': 0.699, 'pos': 0.167, 'compound': 0.6874}
# {'neg': 0.0, 'neu': 0.814, 'pos': 0.186, 'compound': 0.6249}
# {'neg': 0.035, 'neu': 0.965, 'pos': 0.0, 'compound': -0.34}
# {'neg': 0.0, 'neu': 0.646, 'pos': 0.354, 'compound': 0.9382}
# {'neg': 0.0, 'neu': 0.907, 'pos': 0.093, 'compound': 0.5719}
# {'neg': 0.166, 'neu': 0.834, 'pos': 0.0, 'compound': -0.5256}
# {'neg': 0.268, 'neu': 0.732, 'pos': 0.0, 'compound': -0.5106}
# {'neg': 0.085, 'neu': 0.683, 'pos': 0.232, 'compound': 0.9688}
# {'neg': 0.0, 'neu': 0.835, 'pos': 0.165, 'compound': 0.729}
# {'neg': 0.056, 'neu': 0.819, 'pos': 0.125, 'compound': 0.6994}
# {'neg': 0.0, 'neu': 0.831, 'pos': 0.169, 'compound': 0.9001}
# {'neg': 0.043, 'neu': 0.784, 'pos': 0.172, 'compound': 0.7644}
# {'neg': 0.156, 'neu': 0.844, 'pos': 0.0, 'compound': -0.4019}
# {'neg': 0.02, 'neu': 0.858, 'pos': 0.122, 'compound': 0.802}
# {'neg': 0.0, 'neu': 0.873, 'pos': 0.127, 'compound': 0.1531}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.631, 'pos': 0.369, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 0.672, 'pos': 0.328, 'compound': 0.6588}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.148, 'neu': 0.743, 'pos': 0.109, 'compound': -0.2244}
# {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.9652}
# {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.7027}
# {'neg': 0.05, 'neu': 0.824, 'pos': 0.126, 'compound': 0.7712}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.711, 'pos': 0.289, 'compound': 0.6696}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0

# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5411}
# {'neg': 0.049, 'neu': 0.548, 'pos': 0.403, 'compound': 0.9757}
# {'neg': 0.455, 'neu': 0.297, 'pos': 0.248, 'compound': -0.4753}
# {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'compound': 0.561}
# {'neg': 0.039, 'neu': 0.783, 'pos': 0.179, 'compound': 0.9595}
# {'neg': 0.279, 'neu': 0.721, 'pos': 0.0, 'compound': -0.357}
# {'neg': 0.081, 'neu': 0.801, 'pos': 0.118, 'compound': 0.6523}
# {'neg': 0.272, 'neu': 0.728, 'pos': 0.0, 'compound': -0.4574}
# {'neg': 0.0, 'neu': 0.77, 'pos': 0.23, 'compound': 0.4003}
# {'neg': 0.222, 'neu': 0.778, 'pos': 0.0, 'compound': -0.25}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.4767}
# {'neg': 0.071, 'neu': 0.722, 'pos': 0.207, 'compound': 0.643}
# {'neg': 0.184, 'neu': 0.704, 'pos': 0.112, 'compound': -0.2593}
# {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4404}
# {'neg': 0.029, 'neu': 0.739, 'pos': 0.232, 'compound': 0.9764}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.067, 'neu': 0.791, 'pos': 0.141, 'compound': 0.9446}

# %%
Wednesday_df=dfRt.loc[dfRt['day_of_week'] == "Wednesday"]
Wednesday_df.head()
# Out:
#              created_at  favorite_count               id_str  \
# 41  2018-12-26 20:35:25          222929  1078026520021544960
# 121 2018-12-19 23:10:35          118571  1075528854402256896
# 122 2018-12-19 15:05:29           72633  1075406772368785408
# 123 2018-12-19 14:56:11           80635  1075404434862235648
# 124 2018-12-19 14:44:42           65794  1075401544131076096
#
#      in_reply_to_user_id_str  is_retweet  retweet_count                source  \
# 41                       NaN       False          50449    Twitter for iPhone
# 121                      NaN       False          29396  Twitter Media Studio
# 122                      NaN       False          17280    Twitter for iPhone
# 123                      NaN       False          20672    Twitter for iPhone
# 124                      NaN       False          16282    Twitter for iPhone
#
#                                                   text day_of_week
# 41   .@FLOTUS Melania and I were honored to visit o...   Wednesday
# 121  After historic victories against ISIS, it’s ti...   Wednesday
# 122  ....In any event, it goes on and on &amp; the ...   Wednesday
# 123  ...sleazebag AG Eric Schneiderman, who has sin...   Wednesday
# 124  The Trump Foundation has done great work and g...   Wednesday

# %%
# setting text column to a varible
sentences = Wednesday_df["text"]
sentences = sentences.to_string()
# tokenize text column
from nltk import tokenize
sentences = tokenize.sent_tokenize(sentences)
sid = SentimentIntensityAnalyzer()
#WEDNESDAYS 2018
vScore = []
for sentence in sentences:
#     print(sentence)
    ss = sid.polarity_scores(sentence)
#     tCompScores['sentimentScores'] = dfRt['id_str'].map(ss.get('compound'))
#     tCompScores.head()
    score = (ss.get("compound"))
#     how is k working here? How does this format in this manner?
#     for k in sorted(ss):
#         print('{0}: {1}, '.format(k, ss[k]), end='')
#         print()
    print (ss)
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0
'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.7322}
# {'neg': 0.179, 'neu': 0.821, 'pos': 0.0, 'compound': -0.5423}
# {'neg': 0.0, 'neu': 0.716, 'pos': 0.284, 'compound': 0.9721}
# {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'compound': 0.9772}
# {'neg': 0.0, 'neu': 0.701, 'pos': 0.299, 'compound': 0.8955}
# {'neg': 0.137, 'neu': 0.598, 'pos': 0.265, 'compound': 0.9081}
# {'neg': 0.0, 'neu': 0.823, 'pos': 0.177, 'compound': 0.4199}
# {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'compound': 0.4391}

# %%
Thursday_df=dfRt.loc[dfRt['day_of_week'] == "Thursday"]
Thursday_df.head()
# Out:
#             created_at  favorite_count               id_str  \
# 29 2018-12-27 23:23:36          181505  1078431231262502912
# 30 2018-12-27 22:10:07          127963  1078412737603096576
# 31 2018-12-27 21:26:10           85219  1078401678930558976
# 32 2018-12-27 21:13:15            9448  1078398427661250560
# 33 2018-12-27 21:04:24          180032  1078396200842395648
#
#     in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 29                      NaN       False          43776  Twitter for iPhone
# 30                      NaN       False          31411  Twitter for iPhone
# 31                      NaN       False          19652  Twitter for iPhone
# 32                      NaN       False           2510  Twitter for iPhone
# 33                      NaN       False          45971  Twitter for iPhone
#
#                                                  text day_of_week
# 29  CNN &amp; others within the Fake News Universe...    Thursday
# 30  This isn’t about the Wall, everybody knows tha...    Thursday
# 31  Brad Blakeman: “The American people understand...    Thursday
# 32  Brad Blakeman: “The American people understand...    Thursday
# 33           I totally agree! https://t.co/KO8E3bfWfn    Thursday

# %%
# setting text column to a varible
sentences = Thursday_df["text"]
sentences = sentences.to_string()
# tokenize text column
from nltk import tokenize
sentences = tokenize.sent_tokenize(sentences)
sid = SentimentIntensityAnalyzer()
#THURSDAYS 2018
vScore = []
for sentence in sentences:
#     print(sentence)
    ss = sid.polarity_scores(sentence)
#     tCompScores['sentimentScores'] = dfRt['id_str'].map(ss.get('compound'))
#     tCompScores.head()
    score = (ss.get("compound"))
#     how is k working here? How does this format in this manner?
#     for k in sorted(ss):
#         print('{0}: {1}, '.format(k, ss[k]), end='')
#         print()
    print (ss)
# Out:
# {'neg': 0.087, 'neu': 0.842, 'pos': 0.071, 'compound': -0.1528}
# {'neg': 0.037, 'neu': 0.945, 'pos': 0.018, 'compound': -0.3182}
# {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.6588}
# {'neg': 0.085, 'neu': 0.836, 'pos': 0.079, 'compound': -0.1263}
# {'neg': 0.033, 'neu': 0.729, 'pos': 0.237, 'compound': 0.9246}
# {'neg': 0.204, 'neu': 0.796, 'pos': 0.0, 'compound': -0.8139}
# {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.133, 'neu': 0.786, 'pos': 0.081, 'compound': -0.5003}
# {'neg': 0.038, 'neu': 0.769, 'pos': 0.192, 'compound': 0.765}
# {'neg': 0.0, 'neu': 0.774, 'pos': 0.226, 'compound': 0.6573}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.031, 'neu': 0.852, 'pos': 0.117, 'compound': 0.9127}
# {'neg': 0.244, 'neu': 0.618, 'pos': 0.138, 'compound': -0.4404}
# {'neg': 0.083, 'neu': 0.688, 'pos': 0.229, 'compound': 0.7351}
# {'neg': 0.098, 'neu': 0.803, 'pos': 0.098, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, '
neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.9486}
# {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'compound': 0.9468}
# {'neg': 0.098, 'neu': 0.738, 'pos': 0.163, 'compound': 0.6625}
# {'neg': 0.0, 'neu': 0.663, 'pos': 0.337, 'compound': 0.765}
# {'neg': 0.0, 'neu': 0.628, 'pos': 0.372, 'compound': 0.8268}
# {'neg': 0.084, 'neu': 0.698, 'pos': 0.218, 'compound': 0.9754}
# {'neg': 0.053, 'neu': 0.811, 'pos': 0.137, 'compound': 0.8271}
# {'neg': 0.147, 'neu': 0.49, 'pos': 0.363, 'compound': 0.4939}
# {'neg': 0.0, 'neu': 0.579, 'pos': 0.421, 'compound': 0.7027}
# {'neg': 0.0, 'neu': 0.622, 'pos': 0.378, 'compound': 0.7841}
# {'neg': 0.035, 'neu': 0.787, 'pos': 0.177, 'compound': 0.6309}
# {'neg': 0.127, 'neu': 0.696, 'pos': 0.177, 'compound': 0.8852}
# {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'compound': 0.9921}
# {'neg': 0.13, 'neu': 0.739, 'pos': 0.131, 'compound': 0.2577}
# {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.9849}
# {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.6124}
# {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'compound': 0.4675}
# {'neg': 0.0, 'neu': 0.66, 'pos': 0.34, 'compound': 0.8034}
# {'neg': 0.035, 'neu': 0.746, 'pos': 0.219, 'compound': 0.9814}
# {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'compound': 0.7096}
# {'neg': 0.177, 'neu': 0.714, 'pos': 0.109, 'compound': -0.561}
# {'neg': 0.062, 'neu': 0.644, 'pos': 0.294, 'compound': 0.8687}
# {'neg': 0.136, 'neu': 0.737, 'pos': 0.127, 'compound': 0.1531}
# {'neg': 0.043, 'neu': 0.784, 'pos': 0.173, 'compound': 0.9475}
# {'neg': 0.078, 'neu': 0.797, 'pos': 0.125, 'compound': 0.7964}
# {'neg': 0.048, 'neu': 0.829, 'pos': 0.123, 'compound': 0.9442}
# {'neg': 0.136, 'neu': 0.772, 'pos': 0.092, 'compound': -0.347}

# %%
Friday_df=dfRt.loc[dfRt['day_of_week'] == "Friday"]
Friday_df.head()
# Out:
#             created_at  favorite_count               id_str  \
# 24 2018-12-28 14:51:07          113934  1078664648726061056
# 25 2018-12-28 13:06:13          167219  1078638249562775552
# 26 2018-12-28 12:49:26          108226  1078634025412116480
# 27 2018-12-28 12:42:12          101171  1078632205210058752
# 28 2018-12-28 12:16:40          156509  1078625779670503424
#
#     in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 24                      NaN       False          21412  Twitter for iPhone
# 25                      NaN       False          39555  Twitter for iPhone
# 26                      NaN       False          25317  Twitter for iPhone
# 27                      NaN       False          23743  Twitter for iPhone
# 28                      NaN       False          36288  Twitter for iPhone
#
#                                                  text day_of_week
# 24  Thank you to Sean Parnell for the nice comment...      Friday
# 25  .....Honduras, Guatemala and El Salvador are d...      Friday
# 26  .....close the Southern Border. Bring our car ...      Friday
# 27  ....The United States looses soooo much money ...      Friday
# 28  We will be forced to close the Southern Border...      Friday

# %%
# setting text column to a varible
sentences = Friday_df["text"]
sentences = sentences.to_string()
# tokenize text column
from nltk import tokenize
sentences = tokenize.sent_tokenize(sentences)
sid = SentimentIntensityAnalyzer()
#FRIDAYS 2018
vScore = []
for sentence in sentences:
#     print(sentence)
    ss = sid.polarity_scores(sentence)
#     tCompScores['sentimentScores'] = dfRt['id_str'].map(ss.get('compound'))
#     tCompScores.head()
    score = (ss.get("compound"))
#     how is k working here? How does this format in this manner?
#     for k in sorted(ss):
#         print('{0}: {1}, '.format(k, ss[k]), end='')
#         print()
    print (ss)
# Out:
# {'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'compound': 0.6486}
# {'neg': 0.137, 'neu': 0.769, 'pos': 0.094, 'compound': -0.1779}
# {'neg': 0.092, 'neu': 0.709, 'pos': 0.199, 'compound': 0.6248}
# {'neg': 0.0, 'neu': 0.928, 'pos': 0.072, 'compound': 0.4199}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.048, 'neu': 0.788, 'pos': 0.163, 'compound': 0.9471}
# {'neg': 0.0, 'neu': 0.264, 'pos': 0.736, 'compound': 0.4199}
# {'neg': 0.0, 'neu': 0.793, 'pos': 0.207, 'compound': 0.9689}
# {'neg': 0.194, 'neu': 0.744, 'pos': 0.062, 'compound': -0.8947}
# {'neg': 0.088, 'neu': 0.747, 'pos': 0.166, 'compound': 0.7371}
# {'neg': 0.0, 'neu': 0.919, 'pos': 0.081, 'compound': 0.3367}
# {'neg': 0.0, 'neu': 0.862, 'pos': 0.138, 'compound': 0.4927}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.043, 'neu': 0.733, 'pos': 0.223, 'compound': 0.9892}
# {'neg': 0.0, 'neu': 0.852, 'pos': 0.148, 'compound': 0.8236}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.662, 'pos': 0.338, 'compound': 0.8805}
# {'neg': 0.0, 'neu': 0.71, 'pos': 0.29, 'compound': 0.6696}
# {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.9705}
# {'neg': 0.018, 'neu': 0.778, 'pos': 0.204, 'compound': 0.963}
# {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'compound': 0.6588}
# {'neg': 0.0, 'neu': 0.857, 'pos': 0.143, 'compound': 0.3612}
# {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.3818}
# {'neg': 0.0, 'neu': 0.645, 'pos': 0.355, 'compound': 0.8697}
# {'neg': 0.137, 'neu': 0.553, 'pos': 0.31, 'compound': 0.8622}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.058, 'neu': 0.825, 'pos': 0.116, 'compound': 0.4003}
# {'neg': 0.247, 'neu': 0.598, 'pos': 0.156, 'compound': -0.5046}
# {'neg': 0.0, 'neu': 0.599, 'pos': 0.401, 'compound': 0.9405}
# {'neg': 0.077, 'neu': 0.798, 'pos': 0.125, 'compound': 0.6027}
# {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.7901}
# {'neg': 0.076, 'neu': 0.655, 'pos': 0.269, 'compound': 0.8793}
# {'neg': 0.0, 'neu': 0.437, 'pos': 0.563, 'compound': 0.8283}
# {'neg': 0.0, 'neu': 0.747, 'pos': 0.253, 'compound': 0.6588}
# {'neg': 0.21, 'neu': 0.739, 'pos': 0.051, 'compound': -0.8481}
# {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 0.364, 'pos': 0.636, 'compound': 0.7901}
# {'neg': 0.0, 'neu': 0.494, 'pos': 0.506, 'compound': 0.729}
# {'neg': 0.0, 'neu': 0.683, 'pos': 0.317, 'compound': 0.9583}
# {'neg': 0.0, 'neu': 0.308, 'pos': 0.692, 'compound': 0.6696}
# {'neg': 0.065, 'neu': 0.877, 'pos': 0.058, 'compound': -0.1531}
# {'neg': 0.114, 'neu': 0.847, 'pos': 0.039, 'compound': -0.6444}
# {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 

# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.087, 'neu': 0.833, 'pos': 0.08, 'compound': -0.1007}
# {'neg': 0.0, 'neu': 0.591, 'pos': 0.409, 'compound': 0.9536}
# {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.7959}
# {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'compound': 0.6805}
# {'neg': 0.0, 'neu': 0.631, 'pos': 0.369, 'compound': 0.6239}
# {'neg': 0.0, 'neu': 0.793, 'pos': 0.207, 'compound': 0.9313}
# {'neg': 0.0, 'neu': 0.387, 'pos': 0.613, 'compound': 0.8588}
# {'neg': 0.023, 'neu': 0.765, 'pos': 0.212, 'compound': 0.9686}
# {'neg': 0.104, 'neu': 0.785, 'pos': 0.111, 'compound': 0.128}
# {'neg': 0.0, 'neu': 0.858, 'pos': 0.142, 'compound': 0.8832}

# %%
Saturday_df=dfRt.loc[dfRt['day_of_week'] == "Saturday"]
Saturday_df.head()
# Out:
#             created_at  favorite_count               id_str  \
# 17 2018-12-29 21:06:08          109368  1079121410935660544
# 18 2018-12-29 19:25:47          144416  1079096156708319232
# 19 2018-12-29 18:36:17          129861  1079083702943211520
# 20 2018-12-29 18:30:16          120754  1079082188665171968
# 21 2018-12-29 16:03:02          142185  1079045134061371392
#
#     in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 17                      NaN       False          25809  Twitter for iPhone
# 18                      NaN       False          34547  Twitter for iPhone
# 19                      NaN       False          30224  Twitter for iPhone
# 20                      NaN       False          29381  Twitter for iPhone
# 21                      NaN       False          27736  Twitter for iPhone
#
#                                                  text day_of_week
# 17  2018 is being called “THE YEAR OF THE WORKER” ...    Saturday
# 18  For those that naively ask why didn’t the Repu...    Saturday
# 19  ...children in question were very sick before ...    Saturday
# 20  Any deaths of children or others at the Border...    Saturday
# 21  Just had a long and very good call with Presid...    Saturday

# %%
# setting text column to a varible
sentences = Saturday_df["text"]
sentences = sentences.to_string()
# tokenize text column
from nltk import tokenize
sentences = tokenize.sent_tokenize(sentences)
sid = SentimentIntensityAnalyzer()
#SATURDAYS 2018
vScore = []
for sentence in sentences:
#     print(sentence)
    ss = sid.polarity_scores(sentence)
#     tCompScores['sentimentScores'] = dfRt['id_str'].map(ss.get('compound'))
#     tCompScores.head()
    score = (ss.get("compound"))
#     how is k working here? How does this format in this manner?
#     for k in sorted(ss):
#         print('{0}: {1}, '.format(k, ss[k]), end='')
#         print()
    print (ss)
# Out:
# {'neg': 0.075, 'neu': 0.89, 'pos': 0.035, 'compound': -0.5719}
# {'neg': 0.16, 'neu': 0.775, 'pos': 0.065, 'compound': -0.6597}
# {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.8503}
# {'neg': 0.1, 'neu': 0.743, 'pos': 0.156, 'compound': 0.8372}
# {'neg': 0.023, 'neu': 0.81, 'pos': 0.167, 'compound': 0.9252}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5411}
# {'neg': 0.0, 'neu': 0.785, 'pos': 0.215, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'compound': 0.7506}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.119, 'neu': 0.768, 'pos': 0.113, 'compound': 0.2867}
# {'neg': 0.01, 'neu': 0.873, 'pos': 0.117, 'compound': 0.9469}
# {'neg': 0.12, 'neu': 0.649, 'pos': 0.231, 'compound': 0.68}
# {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0
'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.5267}
# {'neg': 0.072, 'neu': 0.792, 'pos': 0.136, 'compound': 0.9369}
# {'neg': 0.06, 'neu': 0.703, 'pos': 0.237, 'compound': 0.7777}
# {'neg': 0.1, 'neu': 0.9, 'pos': 0.0, 'compound': -0.5707}
# {'neg': 0.165, 'neu': 0.669, 'pos': 0.166, 'compound': -0.2441}
# {'neg': 0.071, 'neu': 0.891, 'pos': 0.039, 'compound': -0.6696}
# {'neg': 0.031, 'neu': 0.679, 'pos': 0.291, 'compound': 0.9743}
# {'neg': 0.173, 'neu': 0.753, 'pos': 0.074, 'compound': -0.6755}
# {'neg': 0.0, 'neu': 0.924, 'pos': 0.076, 'compound': 0.2228}
# {'neg': 0.216, 'neu': 0.784, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
Sunday_df=dfRt.loc[dfRt['day_of_week'] == "Sunday"]
Sunday_df.head()
# Out:
#             created_at  favorite_count               id_str  \
# 12 2018-12-30 21:59:44          233722  1079497288605683712
# 13 2018-12-30 16:56:09          131013  1079420891807793152
# 14 2018-12-30 15:28:35          123780  1079398853684707328
# 15 2018-12-30 03:15:36          150249  1079214392758145024
# 16 2018-12-30 03:01:28          118323  1079210835963195392
#
#     in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 12                      NaN       False          61837  Twitter for iPhone
# 13                      NaN       False          32084  Twitter for iPhone
# 14                      NaN       False          25782  Twitter for iPhone
# 15                      NaN       False          44918  Twitter for iPhone
# 16                      NaN       False          30800  Twitter for iPhone
#
#                                                  text day_of_week
# 12  President and Mrs. Obama built/has a ten foot ...      Sunday
# 13  Great work by my Administration over the holid...      Sunday
# 14  Veterans on President Trump’s handling of Bord...      Sunday
# 15  “It turns out to be true now, that the Departm...      Sunday
# 16  “Absolutely nothing” (on Russian Collusion). K...      Sunday

# %%
# setting text column to a varible
sentences = Sunday_df["text"]
sentences = sentences.to_string()
# tokenize text column
from nltk import tokenize
sentences = tokenize.sent_tokenize(sentences)
sid = SentimentIntensityAnalyzer()
#SUNDAYS 2018
vScore = []
for sentence in sentences:
#     print(sentence)
    ss = sid.polarity_scores(sentence)
#     tCompScores['sentimentScores'] = dfRt['id_str'].map(ss.get('compound'))
#     tCompScores.head()
    score = (ss.get("compound"))
#     how is k working here? How does this format in this manner?
#     for k in sorted(ss):
#         print('{0}: {1}, '.format(k, ss[k]), end='')
#         print()
    print (ss)
# Out:
# {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.7845}
# {'neg': 0.092, 'neu': 0.802, 'pos': 0.106, 'compound': 0.8408}
# {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.022, 'neu': 0.704, 'pos': 0.274, 'compound': 0.9815}
# {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.4199}
# {'neg': 0.0, 'neu': 0.829, 'pos': 0.171, 'compound': 0.6739}
# {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'compound': 0.5994}
# {'neg': 0.197, 'neu': 0.578, 'pos': 0.225, 'compound': -0.128}
# {'neg': 0.111, 'neu': 0.667, 'pos': 0.222, 'compound': 0.7561}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.071, 'neu': 0.784, 'pos': 0.145, 'compound': 0.7712}
# {'neg': 0.0, 'neu': 0.518, 'pos': 0.482, 'compound': 0.4199}
# {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.7959}
# {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'compound': 0.4199}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.875}
# {'neg': 0.0, 'neu': 0.462, 'pos': 0.538, 'compound': 0.7901}
# {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'compound': 0.6239}
# {'neg': 0.062, 'neu': 0.75, 'pos': 0.187, 'compound': 0.7452}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.576, 'pos': 0.424, 'compound': 0.7096}
# {'neg': 0.0, 'neu': 0.432, 'pos': 0.568, 'compound': 0.8885}
# {'neg': 0.072, 'neu': 0.756, 'pos': 0.172, 'compound': 0.8934}
# {'neg': 0.053, 'neu': 0.732, 'pos': 0.215, 'compound': 0.8553}
# {'neg': 0.0, 'neu': 0.493, 'pos': 0.507, 'compound': 0.7322}
# {'neg': 0.045, 'neu': 0.87, 'pos': 0.086, 'compound': 0.624}
# {'neg': 0.164, 'neu': 0.75, 'pos': 0.086, 'compound': -0.8588}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.141, 'neu': 0.769, 'pos': 0.09, 'compound': -0.5584}
# {'neg': 0.138, 'neu': 0.711, 'pos': 0.151, 'compound': 0.1531}
# {'neg': 0.0, 'neu': 0.182, 'pos': 0.818, 'compound': 0.6696}
# {'neg': 0.098, 'neu': 0.902, 'pos': 0.0, 'compound': -0.3595}
# {'neg': 0.0, 'neu': 0.904, 'pos': 0.096, 'compound': 0.1779}
# {'neg': 0.301, 'neu': 0.548, 'pos': 0.151, 'compound': -0.2732}
# {'neg': 0.051, 'neu': 0.77, 'pos': 0.179, 'compound': 0.9398}
# {'neg': 0.173, 'neu': 0.558, 'pos': 0.27, 'compound': 0.4084}
# {'neg': 0.0, 'neu': 0.79, 'pos': 0.21, 'compound': 0.9267}
# {'neg': 0.071, 'neu': 0.929, 'pos': 0.0, 'compound': -0.3802}
# {'neg': 0.212, 'neu': 0.788, 'pos': 0.0, 'compound': -0.5423}
# {'neg': 0.022, 'neu': 0.9, 'pos': 0.078, 'compound': 0.629}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.201, 'neu': 0.799, 'pos': 0.0, 'compound': -0.5461}
# {'neg': 0.355, 'neu': 0.645, 'pos': 0.0, 'compound': -0.296}
# {'neg': 0.082, 'neu': 0.744, 'pos': 0.173, 'compound': 0.7027}
# {'neg': 0.027, 'neu': 0.85, 'pos': 0.123, 'compound': 0.9179}
# {'neg': 0.141, 'neu': 0.859, 'pos': 0.0, 'compound': -0.8583}
# {'neg': 0.07, 'neu': 0.718, 'pos': 0.213, 'compound': 0.7488}
# {'neg': 0.038, 'neu': 0.815, 'pos': 0.148, 'compound': 0.807}
# {'neg': 0.083, 'neu': 0.803, 'pos': 0.115, 'compound': 0.4019}
# {'neg': 0.077, 'neu': 0.825, 'pos': 0.097, 'compound': 0.4868}
# {'neg': 0.06, 'neu': 0.845, 'pos': 0.095, 'compound': 0.5754}
# {'neg': 0.0, 'neu': 0.752, 'pos': 0.248, 'compound': 0.9501}
# {'neg': 0.078, 'neu': 0.801, 'pos': 0.122, 'compound': 0.7351}
# {'neg': 0.133, 'neu': 0.667, 'pos': 0.2, 'compound': 0.6808}
# {'neg': 0.069, 'neu': 0.856, 'pos': 0.074, 'compound': 0.399}
# {'neg': 0.042, 'neu': 0.729, 'pos': 0.23, 'compound': 0.9554}
# {'neg': 0.126, 'neu': 0.855, 'pos': 0.019, 'compound': -0.8118}

# %%
# ser variable for seniment analyzer
sid = SentimentIntensityAnalyzer()

# set text column to a varible for vader analysis
sentences = dfRt["text"]

# create list for polarity scores
vScore = []

# run vader on text
for sentence in sentences:
    ss = sid.polarity_scores(sentence)

# append score to list
    vScore.append((ss.get("compound")))

# add list to dataframe for plotting
dfRt["vScore"]= pd.DataFrame(vScore)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dfRt.head()
# Out:
#            created_at  favorite_count               id_str  \
# 0 2018-12-31 23:53:06          136012  1079888205351145472
# 1 2018-12-31 20:02:52           65069  1079830268708556800
# 2 2018-12-31 20:02:52           76721  1079830267274108928
# 3 2018-12-31 15:39:15          127485  1079763923845419008
# 4 2018-12-31 15:37:14          132439  1079763419908243456
#
#    in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 0                      NaN       False          33548  Twitter for iPhone
# 1               25073877.0       False          17456  Twitter for iPhone
# 2                      NaN       False          21030  Twitter for iPhone
# 3                      NaN       False          29610  Twitter for iPhone
# 4                      NaN       False          30957  Twitter for iPhone
#
#                                                 text day_of_week  vScore
# 0            HAPPY NEW YEAR! https://t.co/bHoPDPQ7G6      Monday  0.6932
# 1  ....Senator Schumer, more than a year longer t...      Monday -0.2908
# 2  Heads of countries are calling wanting to know...      Monday  0.8652
# 3  It’s incredible how Democrats can all use thei...      Monday -0.8843
# 4  I’m in the Oval Office. Democrats, come back f...      Monday  0.5707

# %%
dfRt.to_csv('vScore2018.csv',index=False)

# %%
# plot sentiment of tweets according to day of the week
plt.close()
plt.figure(figsize=(15,10))
plt.ylim(-1.2,1.2)
sns.violinplot(x='day_of_week',y='vScore',data=dfRt)
sns.swarmplot(x="day_of_week", y="vScore",data=dfRt, color="black")
plt.xlabel('')
plt.xticks(size=12)
plt.ylabel('VADER Compound Sentiment Score',size=15)
plt.savefig('Season1.png')
# Out:
# <img src="data:image/png;base64,..." width="1500">
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1324: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1328: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
#DEPENDENCIES & MONGO STORAGE
import numpy as np
import requests
import pymongo
from pymongo import MongoClient
import os

# %%
# Save path to 2009 data set in a variable
data_file = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 19\\Project3\\Project3-master\\trump_tweet_data_archive-master\\condensed_2009.json.zip"

# %%
# load tweets into a dataframe
df = pd.read_json(data_file)
df.head()
# Out:
#            created_at  favorite_count      id_str  in_reply_to_user_id_str  \
# 0 2009-12-23 17:38:18              12  6971079756                      NaN
# 1 2009-12-03 19:39:09               6  6312794445                      NaN
# 2 2009-11-26 19:55:38              11  6090839867                      NaN
# 3 2009-11-16 21:06:10               3  5775731054                      NaN
# 4 2009-11-02 14:57:56               6  5364614040                      NaN
#
#    is_retweet  retweet_count              source  \
# 0       False             28  Twitter Web Client
# 1       False             33  Twitter Web Client
# 2       False             13  Twitter Web Client
# 3       False              5  Twitter Web Client
# 4       False              7  Twitter Web Client
#
#                                                 text
# 0  From Donald Trump: Wishing everyone a wonderfu...
# 1  Trump International Tower in Chicago ranked 6t...
# 2  Wishing you and yours a very Happy and Bountif...
# 3  Donald Trump Partners with TV1 on New Reality ...
# 4  --Work has begun, ahead of schedule, to build ...

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.TrumpTweets

# Connection to the collection
#collection = db.Tweets2009

# %%
# Read the row from data_file to create a dictionary
for _, row in df.iterrows():
   dic = {
       'Date':row["created_at"],
       'StringID':row["id_str"],
       'Text': row["text"],
       'RetweetCount': row["retweet_count"],
       'Source': row["source"]
       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# Save path to 2010-18 data set in a variable
data_file2010 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 19\\Project3\\Project3-master\\trump_tweet_data_archive-master\\condensed_2010.json.zip"
data_file2011 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 19\\Project3\\Project3-master\\trump_tweet_data_archive-master\\condensed_2011.json.zip"
data_file2012 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 19\\Project3\\Project3-master\\trump_tweet_data_archive-master\\condensed_2012.json.zip"
data_file2013 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 19\\Project3\\Project3-master\\trump_tweet_data_archive-master\\condensed_2013.json.zip"
data_file2014 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 19\\Project3\\Project3-master\\trump_tweet_data_archive-master\\condensed_2014.json.zip"
data_file2015 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 19\\Project3\\Project3-master\\trump_tweet_data_archive-master\\condensed_2015.json.zip"
data_file2016 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 19\\Project3\\Project3-master\\trump_tweet_data_archive-master\\condensed_2016.json.zip"
data_file2017 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 19\\Project3\\Project3-master\\trump_tweet_data_archive-master\\condensed_2017.json.zip"
data_file2018 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 19\\Project3\\Project3-master\\trump_tweet_data_archive-master\\condensed_2018.json.zip"

# %%
# load tweets into a dataframe
df2010 = pd.read_json(data_file2010)
df2011 = pd.read_json(data_file2011)
df2012 = pd.read_json(data_file2012)
df2013 = pd.read_json(data_file2013)
df2014 = pd.read_json(data_file2014)
df2015 = pd.read_json(data_file2015)
df2016 = pd.read_json(data_file2016)
df2017 = pd.read_json(data_file2017)
df2018 = pd.read_json(data_file2018)

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.TrumpTweets

# Connection to the collection
#collection = db.Tweets2010

# Read the row from data_file to create a dictionary
for _, row in df2010.iterrows():
   dic = {
       'Date':row["created_at"],
       'StringID':row["id_str"],
       'Text': row["text"],
       'RetweetCount': row["retweet_count"],
       'Source': row["source"]
       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.TrumpTweets

# Connection to the collection
#collection = db.Tweets2011

# Read the row from data_file to create a dictionary
for _, row in df2011.iterrows():
   dic = {
       'Date':row["created_at"],
       'StringID':row["id_str"],
       'Text': row["text"],
       'RetweetCount': row["retweet_count"],
       'Source': row["source"]
       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.TrumpTweets

# Connection to the collection
#collection = db.Tweets2012

# Read the row from data_file to create a dictionary
for _, row in df2012.iterrows():
   dic = {
       'Date':row["created_at"],
       'StringID':row["id_str"],
       'Text': row["text"],
       'RetweetCount': row["retweet_count"],
       'Source': row["source"]
       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.TrumpTweets

# Connection to the collection
#collection = db.Tweets2013

# Read the row from data_file to create a dictionary
for _, row in df2013.iterrows():
   dic = {
       'Date':row["created_at"],
       'StringID':row["id_str"],
       'Text': row["text"],
       'RetweetCount': row["retweet_count"],
       'Source': row["source"]
       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.TrumpTweets

# Connection to the collection
#collection = db.Tweets2014

# Read the row from data_file to create a dictionary
for _, row in df2014.iterrows():
   dic = {
       'Date':row["created_at"],
       'StringID':row["id_str"],
       'Text': row["text"],
       'RetweetCount': row["retweet_count"],
       'Source': row["source"]
       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.TrumpTweets

# Connection to the collection
#collection = db.Tweets2015

# Read the row from data_file to create a dictionary
for _, row in df2015.iterrows():
   dic = {
       'Date':row["created_at"],
       'StringID':row["id_str"],
       'Text': row["text"],
       'RetweetCount': row["retweet_count"],
       'Source': row["source"]
       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.TrumpTweets

# Connection to the collection
#collection = db.Tweets2016

# Read the row from data_file to create a dictionary
for _, row in df2016.iterrows():
   dic = {
       'Date':row["created_at"],
       'StringID':row["id_str"],
       'Text': row["text"],
       'RetweetCount': row["retweet_count"],
       'Source': row["source"]
       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.TrumpTweets

# Connection to the collection
#collection = db.Tweets2017

# Read the row from data_file to create a dictionary
for _, row in df2017.iterrows():
   dic = {
       'Date':row["created_at"],
       'StringID':row["id_str"],
       'Text': row["text"],
       'RetweetCount': row["retweet_count"],
       'Source': row["source"]
       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.TrumpTweets

# Connection to the collection
#collection = db.Tweets2018

# Read the row from data_file to create a dictionary
for _, row in df2018.iterrows():
   dic = {
       'Date':row["created_at"],
       'StringID':row["id_str"],
       'Text': row["text"],
       'RetweetCount': row["retweet_count"],
       'Source': row["source"]
       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)
