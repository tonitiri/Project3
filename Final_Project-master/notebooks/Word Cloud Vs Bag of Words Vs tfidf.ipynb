# %%
import nltk
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import KFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.externals import joblib
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
import pandas as pd
import matplotlib.pyplot as plt
import re
#from nltk.stem.wordnet import WordNetLemmatizerLoad training dataset to Pandas and preview the top rows.

# %%
# load train data
data = pd.read_json('condensed_2018.json')
data
# Out:
#               created_at  favorite_count               id_str  \
# 0    2018-12-31 23:53:06          136012  1079888205351145472
# 1    2018-12-31 20:02:52           65069  1079830268708556800
# 2    2018-12-31 20:02:52           76721  1079830267274108928
# 3    2018-12-31 15:39:15          127485  1079763923845419008
# 4    2018-12-31 15:37:14          132439  1079763419908243456
# 5    2018-12-31 15:33:15            4217  1079762413589807104
# 6    2018-12-31 14:38:52          112735  1079748730058870784
# 7    2018-12-31 13:29:32           91523  1079731279032172544
# 8    2018-12-31 13:19:13           72758  1079728684427341824
# 9    2018-12-31 13:12:40          101470  1079727034673311744
# 10   2018-12-31 13:03:05           79534  1079724622868819968
# 11   2018-12-31 12:51:22           97178  1079721675346923520
# 12   2018-12-30 21:59:44          233722  1079497288605683712
# 13   2018-12-30 16:56:09          131013  1079420891807793152
# 14   2018-12-30 15:28:35          123780  1079398853684707328
# 15   2018-12-30 03:15:36          150249  1079214392758145024
# 16   2018-12-30 03:01:28          118323  1079210835963195392
# 17   2018-12-29 21:06:08          109368  1079121410935660544
# 18   2018-12-29 19:25:47          144416  1079096156708319232
# 19   2018-12-29 18:36:17          129861  1079083702943211520
# 20   2018-12-29 18:30:16          120754  1079082188665171968
# 21   2018-12-29 16:03:02          142185  1079045134061371392
# 22   2018-12-29 15:52:24          127645  1079042460800696320
# 23   2018-12-29 15:42:50          112124  1079040052234203136
# 24   2018-12-28 14:51:07          113934  1078664648726061056
# 25   2018-12-28 13:06:13          167219  1078638249562775552
# 26   2018-12-28 12:49:26          108226  1078634025412116480
# 27   2018-12-28 12:42:12          101171  1078632205210058752
# 28   2018-12-28 12:16:40          156509  1078625779670503424
# 29   2018-12-27 23:23:36          181505  1078431231262502912
# ...                  ...             ...                  ...
# 3480 2018-01-12 12:20:32           92162   951790999784783872
# 3481 2018-01-12 12:09:58          110177   951788342647107584
# 3482 2018-01-12 11:59:02           83977   951785587765280768
# 3483 2018-01-12 04:57:57          125213   951679619341737984
# 3484 2018-01-12 04:42:25          122744   951675713089888256
# 3485 2018-01-12 03:01:20           99213   951650274032209920
# 3486 2018-01-12 02:53:05          115604   951648197440569344
# 3487 2018-01-12 02:49:56           73432   951647402599026688
# 3488 2018-01-12 02:47:17           68224   951646736233189376
# 3489 2018-01-12 02:43:56           76146   951645893513613312
# 3490 2018-01-11 23:27:03           59300   951596346011680768
# 3491 2018-01-11 15:37:54           62600   951478281303416832
# 3492 2018-01-11 14:14:51           60560   951457382651056128
# 3493 2018-01-11 13:11:46           84555   951441504203104256
# 3494 2018-01-11 12:33:21           72410   951431836030459904
# 3495 2018-01-11 11:43:59           96789   951419415794511872
# 3496 2018-01-11 11:33:06           82158   951416674808467456
# 3497 2018-01-11 04:29:02          176601   951309956720087040
# 3498 2018-01-10 23:37:41           89943   951236634095308800
# 3499 2018-01-10 23:07:48           69057   951229113897013248
# 3500 2018-01-10 21:31:30           50505   951204878562549760
# 3501 2018-01-10 20:08:37           56051   951184020150382592
# 3502 2018-01-10 15:14:15          119548   951109942685126656
# 3503 2018-01-10 15:00:29           92227   951106475254059008
# 3504 2018-01-10 14:11:13          108152   951094078661414912
# 3505 2018-01-10 04:23:58           60252   950946293077209088
# 3506 2018-01-10 03:48:26           51951   950937350003183616
# 3507 2018-01-10 00:16:57          123413   950884128379035648
# 3508 2018-01-09 23:59:38               0   950879772644659200
# 3509 2018-01-09 23:07:09           82151   950866561153331200
#
#       in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 0                         NaN       False          33548  Twitter for iPhone
# 1                  25073877.0       False          17456  Twitter for iPhone
# 2                         NaN       False          21030  Twitter for iPhone
# 3                         NaN       False          29610  Twitter for iPhone
# 4                         NaN       False          30957  Twitter for iPhone
# 5                         NaN       False           1123  Twitter for iPhone
# 6                         NaN       False          25463  Twitter for iPhone
# 7                         NaN       False          22079  Twitter for iPhone
# 8                         NaN       False          15152  Twitter for iPhone
# 9                         NaN       False          22119  Twitter for iPhone
# 10                        NaN       False          17467  Twitter for iPhone
# 11                        NaN       False          20873  Twitter for iPhone
# 12                        NaN       False          61837  Twitter for iPhone
# 13                        NaN       False          32084  Twitter for iPhone
# 14                        NaN       False          25782  Twitter for iPhone
# 15                        NaN       False          44918  Twitter for iPhone
# 16                        NaN       False          30800  Twitter for iPhone
# 17                        NaN       False          25809  Twitter for iPhone
# 18                        NaN       False          34547  Twitter for iPhone
# 19                        NaN       False          30224  Twitter for iPhone
# 20                        NaN       False          29381  Twitter for iPhone
# 21                        NaN       False          27736  Twitter for iPhone
# 22                        NaN       False          30025  Twitter for iPhone
# 23                        NaN       False          32062  Twitter for iPhone
# 24                        NaN       False          21412  Twitter for iPhone
# 25                        NaN       False          39555  Twitter for iPhone
# 26                        NaN       False          25317  Twitter for iPhone
# 27                        NaN       False          23743  Twitter for iPhone
# 28                        NaN       False          36288  Twitter for iPhone
# 29                        NaN       False          43776  Twitter for iPhone
# ...                       ...         ...            ...                 ...
# 3480                      NaN       False          23043  Twitter for iPhone
# 3481                      NaN       False          24462  Twitter for iPhone
# 3482                      NaN       False          21748  Twitter for iPhone
# 3483                      NaN       False          30085  Twitter for iPhone
# 3484                      NaN       False          29526  Twitter for iPhone
# 3485                      NaN       False          23043  Twitter for iPhone
# 3486                      NaN       False          26034  Twitter for iPhone
# 3487                      NaN       False          19199  Twitter for iPhone
# 3488                      NaN       False          13261  Twitter for iPhone
# 3489                      NaN       False          15578  Twitter for iPhone
# 3490                      NaN       False          13781        Media Studio
# 3491                      NaN       False          15213  Twitter Web Client
# 3492               25073877.0       False          12423  Twitter for iPhone
# 3493                      NaN       False          16253  Twitter for iPhone
# 3494                      NaN       False          17274  Twitter for iPhone
# 3495                      NaN       False          21318  Twitter for iPhone
# 3496                      NaN       False          22798  Twitter for iPhone
# 3497                      NaN       False          36627  Twitter for iPhone
# 3498                      NaN       False          23085  Twitter for iPhone
# 3499                      NaN       False          15828  Twitter for iPhone
# 3500                      NaN       False           9570  Twitter for iPhone
# 3501                      NaN       False          11875  Twitter for iPhone
# 3502                      NaN       False          28805  Twitter for iPhone
# 3503                      NaN       False          22740  Twitter for iPhone
# 3504                      NaN       False          26665  Twitter for iPhone
# 3505                      NaN       False          13822  Twitter for iPhone
# 3506                      NaN       False          11893  Twitter for iPhone
# 3507                      NaN       False          24552  Twitter for iPhone
# 3508                      NaN        True          11716  Twitter for iPhone
# 3509                      NaN       False          19481  Twitter for iPhone
#
#                                                    text
# 0               HAPPY NEW YEAR! https://t.co/bHoPDPQ7G6
# 1     ....Senator Schumer, more than a year longer t...
# 2     Heads of countries are calling wanting to know...
# 3     It’s incredible how Democrats can all use thei...
# 4     I’m in the Oval Office. Democrats, come back f...
# 5     I’m in the Oval Office. Democrats, come back f...
# 6     I am the only person in America who could say ...
# 7     I campaigned on Border Security, which you can...
# 8     .....Except the results are FAR BETTER than I ...
# 9     ...I campaigned on getting out of Syria and ot...
# 10    If anybody but Donald Trump did what I did in ...
# 11    An all concrete Wall was NEVER ABANDONED, as h...
# 12    President and Mrs. Obama built/has a ten foot ...
# 13    Great work by my Administration over the holid...
# 14    Veterans on President Trump’s handling of Bord...
# 15    “It turns out to be true now, that the Departm...
# 16    “Absolutely nothing” (on Russian Collusion). K...
# 17    2018 is being called “THE YEAR OF THE WORKER” ...
# 18    For those that naively ask why didn’t the Repu...
# 19    ...children in question were very sick before ...
# 20    Any deaths of children or others at the Border...
# 21    Just had a long and very good call with Presid...
# 22    I am in the White House waiting for the Democr...
# 23    The Mueller Angry Democrats recently deleted a...
# 24    Thank you to Sean Parnell for the nice comment...
# 25    .....Honduras, Guatemala and El Salvador are d...
# 26    .....close the Southern Border. Bring our car ...
# 27    ....The United States looses soooo much money ...
# 28    We will be forced to close the Southern Border...
# 29    CNN &amp; others within the Fake News Universe...
# ...                                                 ...
# 3480  ....Because of the Democrats not being interes...
# 3481  ....countries which are doing badly. I want a ...
# 3482  The so-called bipartisan DACA deal presented y...
# 3483  Reason I canceled my trip to London is that I ...
# 3484  The Democrats seem intent on having people and...
# 3485  Democrat Dianne Feinstein should never have re...
# 3486  Chrysler is moving a massive plant from Mexico...
# 3487  More great news as a result of historical Tax ...
# 3488  Small Business Poll has highest approval numbe...
# 3489  Thank you Adam Levine, The Federalist, in inte...
# 3490  Yesterday, I signed the #INTERDICTAct (H.R. 21...
# 3491  Great news, as a result of our TAX CUTS &amp; ...
# 3492  With that being said, I have personally direct...
# 3493  “45 year low in illegal immigration this year....
# 3494  “House votes on controversial FISA ACT today.”...
# 3495  In new Quinnipiac Poll, 66% of people feel the...
# 3496  Disproven and paid for by Democrats “Dossier u...
# 3497  Good news: Toyota and Mazda announce giant new...
# 3498  Cutting taxes and simplifying regulations make...
# 3499  The United States needs the security of the Wa...
# 3500  Today, it was my great honor to welcome Prime ...
# 3501  I want to thank my @Cabinet for working tirele...
# 3502  The single greatest Witch Hunt in American his...
# 3503  The fact that Sneaky Dianne Feinstein, who has...
# 3504  It just shows everyone how broken and unfair o...
# 3505  .@ICEgov HSI agents and ERO officers, on behal...
# 3506  Thank you @GOPLeader Kevin McCarthy! Couldn’t ...
# 3507  As I made very clear today, our country needs ...
# 3508  RT @Scavino45: “Utilities cutting rates, cite ...
# 3509  Today, it was my great honor to sign a new Exe...
#
# [3510 rows x 8 columns]

# %%
# drop retweets
data = data[~data.text.str.startswith('RT')]

# %%
data
# Out:
#               created_at  favorite_count               id_str  \
# 0    2018-12-31 23:53:06          136012  1079888205351145472
# 1    2018-12-31 20:02:52           65069  1079830268708556800
# 2    2018-12-31 20:02:52           76721  1079830267274108928
# 3    2018-12-31 15:39:15          127485  1079763923845419008
# 4    2018-12-31 15:37:14          132439  1079763419908243456
# 5    2018-12-31 15:33:15            4217  1079762413589807104
# 6    2018-12-31 14:38:52          112735  1079748730058870784
# 7    2018-12-31 13:29:32           91523  1079731279032172544
# 8    2018-12-31 13:19:13           72758  1079728684427341824
# 9    2018-12-31 13:12:40          101470  1079727034673311744
# 10   2018-12-31 13:03:05           79534  1079724622868819968
# 11   2018-12-31 12:51:22           97178  1079721675346923520
# 12   2018-12-30 21:59:44          233722  1079497288605683712
# 13   2018-12-30 16:56:09          131013  1079420891807793152
# 14   2018-12-30 15:28:35          123780  1079398853684707328
# 15   2018-12-30 03:15:36          150249  1079214392758145024
# 16   2018-12-30 03:01:28          118323  1079210835963195392
# 17   2018-12-29 21:06:08          109368  1079121410935660544
# 18   2018-12-29 19:25:47          144416  1079096156708319232
# 19   2018-12-29 18:36:17          129861  1079083702943211520
# 20   2018-12-29 18:30:16          120754  1079082188665171968
# 21   2018-12-29 16:03:02          142185  1079045134061371392
# 22   2018-12-29 15:52:24          127645  1079042460800696320
# 23   2018-12-29 15:42:50          112124  1079040052234203136
# 24   2018-12-28 14:51:07          113934  1078664648726061056
# 25   2018-12-28 13:06:13          167219  1078638249562775552
# 26   2018-12-28 12:49:26          108226  1078634025412116480
# 27   2018-12-28 12:42:12          101171  1078632205210058752
# 28   2018-12-28 12:16:40          156509  1078625779670503424
# 29   2018-12-27 23:23:36          181505  1078431231262502912
# ...                  ...             ...                  ...
# 3479 2018-01-12 12:28:58          103655   951793123985973248
# 3480 2018-01-12 12:20:32           92162   951790999784783872
# 3481 2018-01-12 12:09:58          110177   951788342647107584
# 3482 2018-01-12 11:59:02           83977   951785587765280768
# 3483 2018-01-12 04:57:57          125213   951679619341737984
# 3484 2018-01-12 04:42:25          122744   951675713089888256
# 3485 2018-01-12 03:01:20           99213   951650274032209920
# 3486 2018-01-12 02:53:05          115604   951648197440569344
# 3487 2018-01-12 02:49:56           73432   951647402599026688
# 3488 2018-01-12 02:47:17           68224   951646736233189376
# 3489 2018-01-12 02:43:56           76146   951645893513613312
# 3490 2018-01-11 23:27:03           59300   951596346011680768
# 3491 2018-01-11 15:37:54           62600   951478281303416832
# 3492 2018-01-11 14:14:51           60560   951457382651056128
# 3493 2018-01-11 13:11:46           84555   951441504203104256
# 3494 2018-01-11 12:33:21           72410   951431836030459904
# 3495 2018-01-11 11:43:59           96789   951419415794511872
# 3496 2018-01-11 11:33:06           82158   951416674808467456
# 3497 2018-01-11 04:29:02          176601   951309956720087040
# 3498 2018-01-10 23:37:41           89943   951236634095308800
# 3499 2018-01-10 23:07:48           69057   951229113897013248
# 3500 2018-01-10 21:31:30           50505   951204878562549760
# 3501 2018-01-10 20:08:37           56051   951184020150382592
# 3502 2018-01-10 15:14:15          119548   951109942685126656
# 3503 2018-01-10 15:00:29           92227   951106475254059008
# 3504 2018-01-10 14:11:13          108152   951094078661414912
# 3505 2018-01-10 04:23:58           60252   950946293077209088
# 3506 2018-01-10 03:48:26           51951   950937350003183616
# 3507 2018-01-10 00:16:57          123413   950884128379035648
# 3509 2018-01-09 23:07:09           82151   950866561153331200
#
#       in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 0                         NaN       False          33548  Twitter for iPhone
# 1                  25073877.0       False          17456  Twitter for iPhone
# 2                         NaN       False          21030  Twitter for iPhone
# 3                         NaN       False          29610  Twitter for iPhone
# 4                         NaN       False          30957  Twitter for iPhone
# 5                         NaN       False           1123  Twitter for iPhone
# 6                         NaN       False          25463  Twitter for iPhone
# 7                         NaN       False          22079  Twitter for iPhone
# 8                         NaN       False          15152  Twitter for iPhone
# 9                         NaN       False          22119  Twitter for iPhone
# 10                        NaN       False          17467  Twitter for iPhone
# 11                        NaN       False          20873  Twitter for iPhone
# 12                        NaN       False          61837  Twitter for iPhone
# 13                        NaN       False          32084  Twitter for iPhone
# 14                        NaN       False          25782  Twitter for iPhone
# 15                        NaN       False          44918  Twitter for iPhone
# 16                        NaN       False          30800  Twitter for iPhone
# 17                        NaN       False          25809  Twitter for iPhone
# 18                        NaN       False          34547  Twitter for iPhone
# 19                        NaN       False          30224  Twitter for iPhone
# 20                        NaN       False          29381  Twitter for iPhone
# 21                        NaN       False          27736  Twitter for iPhone
# 22                        NaN       False          30025  Twitter for iPhone
# 23                        NaN       False          32062  Twitter for iPhone
# 24                        NaN       False          21412  Twitter for iPhone
# 25                        NaN       False          39555  Twitter for iPhone
# 26                        NaN       False          25317  Twitter for iPhone
# 27                        NaN       False          23743  Twitter for iPhone
# 28                        NaN       False          36288  Twitter for iPhone
# 29                        NaN       False          43776  Twitter for iPhone
# ...                       ...         ...            ...                 ...
# 3479                      NaN       False          24795  Twitter for iPhone
# 3480                      NaN       False          23043  Twitter for iPhone
# 3481                      NaN       False          24462  Twitter for iPhone
# 3482                      NaN       False          21748  Twitter for iPhone
# 3483                      NaN       False          30085  Twitter for iPhone
# 3484                      NaN       False          29526  Twitter for iPhone
# 3485                      NaN       False          23043  Twitter for iPhone
# 3486                      NaN       False          26034  Twitter for iPhone
# 3487                      NaN       False          19199  Twitter for iPhone
# 3488                      NaN       False          13261  Twitter for iPhone
# 3489                      NaN       False          15578  Twitter for iPhone
# 3490                      NaN       False          13781        Media Studio
# 3491                      NaN       False          15213  Twitter Web Client
# 3492               25073877.0       False          12423  Twitter for iPhone
# 3493                      NaN       False          16253  Twitter for iPhone
# 3494                      NaN       False          17274  Twitter for iPhone
# 3495                      NaN       False          21318  Twitter for iPhone
# 3496                      NaN       False          22798  Twitter for iPhone
# 3497                      NaN       False          36627  Twitter for iPhone
# 3498                      NaN       False          23085  Twitter for iPhone
# 3499                      NaN       False          15828  Twitter for iPhone
# 3500                      NaN       False           9570  Twitter for iPhone
# 3501                      NaN       False          11875  Twitter for iPhone
# 3502                      NaN       False          28805  Twitter for iPhone
# 3503                      NaN       False          22740  Twitter for iPhone
# 3504                      NaN       False          26665  Twitter for iPhone
# 3505                      NaN       False          13822  Twitter for iPhone
# 3506                      NaN       False          11893  Twitter for iPhone
# 3507                      NaN       False          24552  Twitter for iPhone
# 3509                      NaN       False          19481  Twitter for iPhone
#
#                                                    text
# 0               HAPPY NEW YEAR! https://t.co/bHoPDPQ7G6
# 1     ....Senator Schumer, more than a year longer t...
# 2     Heads of countries are calling wanting to know...
# 3     It’s incredible how Democrats can all use thei...
# 4     I’m in the Oval Office. Democrats, come back f...
# 5     I’m in the Oval Office. Democrats, come back f...
# 6     I am the only person in America who could say ...
# 7     I campaigned on Border Security, which you can...
# 8     .....Except the results are FAR BETTER than I ...
# 9     ...I campaigned on getting out of Syria and ot...
# 10    If anybody but Donald Trump did what I did in ...
# 11    An all concrete Wall was NEVER ABANDONED, as h...
# 12    President and Mrs. Obama built/has a ten foot ...
# 13    Great work by my Administration over the holid...
# 14    Veterans on President Trump’s handling of Bord...
# 15    “It turns out to be true now, that the Departm...
# 16    “Absolutely nothing” (on Russian Collusion). K...
# 17    2018 is being called “THE YEAR OF THE WORKER” ...
# 18    For those that naively ask why didn’t the Repu...
# 19    ...children in question were very sick before ...
# 20    Any deaths of children or others at the Border...
# 21    Just had a long and very good call with Presid...
# 22    I am in the White House waiting for the Democr...
# 23    The Mueller Angry Democrats recently deleted a...
# 24    Thank you to Sean Parnell for the nice comment...
# 25    .....Honduras, Guatemala and El Salvador are d...
# 26    .....close the Southern Border. Bring our car ...
# 27    ....The United States looses soooo much money ...
# 28    We will be forced to close the Southern Border...
# 29    CNN &amp; others within the Fake News Universe...
# ...                                                 ...
# 3479  The language used by me at the DACA meeting wa...
# 3480  ....Because of the Democrats not being interes...
# 3481  ....countries which are doing badly. I want a ...
# 3482  The so-called bipartisan DACA deal presented y...
# 3483  Reason I canceled my trip to London is that I ...
# 3484  The Democrats seem intent on having people and...
# 3485  Democrat Dianne Feinstein should never have re...
# 3486  Chrysler is moving a massive plant from Mexico...
# 3487  More great news as a result of historical Tax ...
# 3488  Small Business Poll has highest approval numbe...
# 3489  Thank you Adam Levine, The Federalist, in inte...
# 3490  Yesterday, I signed the #INTERDICTAct (H.R. 21...
# 3491  Great news, as a result of our TAX CUTS &amp; ...
# 3492  With that being said, I have personally direct...
# 3493  “45 year low in illegal immigration this year....
# 3494  “House votes on controversial FISA ACT today.”...
# 3495  In new Quinnipiac Poll, 66% of people feel the...
# 3496  Disproven and paid for by Democrats “Dossier u...
# 3497  Good news: Toyota and Mazda announce giant new...
# 3498  Cutting taxes and simplifying regulations make...
# 3499  The United States needs the security of the Wa...
# 3500  Today, it was my great honor to welcome Prime ...
# 3501  I want to thank my @Cabinet for working tirele...
# 3502  The single greatest Witch Hunt in American his...
# 3503  The fact that Sneaky Dianne Feinstein, who has...
# 3504  It just shows everyone how broken and unfair o...
# 3505  .@ICEgov HSI agents and ERO officers, on behal...
# 3506  Thank you @GOPLeader Kevin McCarthy! Couldn’t ...
# 3507  As I made very clear today, our country needs ...
# 3509  Today, it was my great honor to sign a new Exe...
#
# [3046 rows x 8 columns]

# %%
# get a word count per sentence column
def word_count(sentence):
    return len(sentence.split())
    
data['word count'] = data['text'].apply(word_count)
data.head(5)
# Out:
# C:\Users\Hailu\OneDrive\Documents\PREWORK_HLS\Anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#            created_at  favorite_count               id_str  \
# 0 2018-12-31 23:53:06          136012  1079888205351145472
# 1 2018-12-31 20:02:52           65069  1079830268708556800
# 2 2018-12-31 20:02:52           76721  1079830267274108928
# 3 2018-12-31 15:39:15          127485  1079763923845419008
# 4 2018-12-31 15:37:14          132439  1079763419908243456
#
#    in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 0                      NaN       False          33548  Twitter for iPhone
# 1               25073877.0       False          17456  Twitter for iPhone
# 2                      NaN       False          21030  Twitter for iPhone
# 3                      NaN       False          29610  Twitter for iPhone
# 4                      NaN       False          30957  Twitter for iPhone
#
#                                                 text  word count
# 0            HAPPY NEW YEAR! https://t.co/bHoPDPQ7G6           4
# 1  ....Senator Schumer, more than a year longer t...          38
# 2  Heads of countries are calling wanting to know...          41
# 3  It’s incredible how Democrats can all use thei...          53
# 4  I’m in the Oval Office. Democrats, come back f...          44

# %%
# get most common words in training dataset
all_words = []
for line in list(data['text']):
    words = line.split()
    for word in words:
        all_words.append(word.lower())
    
    
#Counter(all_words).most_common(10)

# %%
# plot word frequency distribution of first few words
plt.figure(figsize=(12,5))
plt.title('Top 25 most common words')
plt.xticks(fontsize=13, rotation=90)
fd = nltk.FreqDist(all_words)
fd.plot(25,cumulative=False)
# log-log plot
word_counts = sorted(Counter(all_words).values(), reverse=True)
plt.figure(figsize=(12,5))
plt.loglog(word_counts, linestyle='-', linewidth=1.5)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
plt.title('log-log plot of words frequency')
# Out:
# Text(0.5, 1.0, 'log-log plot of words frequency')

# %%
# create column names
col_names=['created_at','favorite_count','id_str','in_reply_to_user_id_str','is_retweet','retweet_count','source','text']
# read json
data = pd.read_json('condensed_2018.json')
# check head
data.head()
# Out:
#            created_at  favorite_count               id_str  \
# 0 2018-12-31 23:53:06          136012  1079888205351145472
# 1 2018-12-31 20:02:52           65069  1079830268708556800
# 2 2018-12-31 20:02:52           76721  1079830267274108928
# 3 2018-12-31 15:39:15          127485  1079763923845419008
# 4 2018-12-31 15:37:14          132439  1079763419908243456
#
#    in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 0                      NaN       False          33548  Twitter for iPhone
# 1               25073877.0       False          17456  Twitter for iPhone
# 2                      NaN       False          21030  Twitter for iPhone
# 3                      NaN       False          29610  Twitter for iPhone
# 4                      NaN       False          30957  Twitter for iPhone
#
#                                                 text
# 0            HAPPY NEW YEAR! https://t.co/bHoPDPQ7G6
# 1  ....Senator Schumer, more than a year longer t...
# 2  Heads of countries are calling wanting to know...
# 3  It’s incredible how Democrats can all use thei...
# 4  I’m in the Oval Office. Democrats, come back f...

# %%
# define punctuation
punctuation = !"#$%&'()*+, -./:;<=>?@[\]^_`{|}~

# helper function to clean tweets
def processTweet(tweet):
    # Remove HTML special entities (e.g. &amp;)
    tweet = re.sub(r'\&\w*;', '', tweet)
    #Convert @username to AT_USER
    tweet = re.sub('@[^\s]+','',tweet)
    # Remove tickers
    tweet = re.sub(r'\$\w*', '', tweet)
    # To lowercase
    tweet = tweet.lower()
    # Remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*\/\w*', '', tweet)
    # Remove hashtags
    tweet = re.sub(r'#\w*', '', tweet)
    # Remove Punctuation and split 's, 't, 've with a space for filter
    #tweet = re.sub(r'[' + punctuation.replace('@', '') + ']+', ' ', tweet)
    tweet.replace('@','')
    # Remove words with 2 or fewer letters
    tweet = re.sub(r'\b\w{1,2}\b', '', tweet)
    # Remove whitespace (including new line characters)
    tweet = re.sub(r'\s\s+', ' ', tweet)
    # Remove single space remaining at the front of the tweet.
    tweet = tweet.lstrip(' ') 
    # Remove characters beyond Basic Multilingual Plane (BMP) of Unicode:
    tweet = ''.join(c for c in tweet if c <= '\uFFFF') 
    return tweet
# ______________________________________________________________
# clean dataframe's text column
data['text'] = data['text'].apply(processTweet)
# preview some cleaned tweets
data['text'].head()
# Out:
# 0                                     happy new year!
# 1    ....senator schumer, more than year longer tha...
# 2    heads countries are calling wanting know why s...
# 3    ’ incredible how democrats can all use their r...
# 4    ’ the oval office. democrats, come back from v...
# Name: text, dtype: object

# %%
# most common words in twitter dataset
all_words = []
for line in list(data['text']):
    words = line.split()
    for word in words:
        all_words.append(word.lower())
# plot word frequency distribution of first few words
plt.figure(figsize=(12,5))
plt.xticks(fontsize=13, rotation=90)
fd = nltk.FreqDist(all_words)
fd.plot(25,cumulative=False)
# log-log of all words 
#word_counts = sorted(Counter(all_words).values(), reverse=True)plt.figure(figsize=(12,5))
plt.loglog(word_counts, linestyle='-', linewidth=1.5)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
# Out:
# Text(0.5, 0, 'Word Rank')

# %%
  import string
# tokenize helper function
def text_process(raw_text):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char for char in list(raw_text) if char not in string.punctuation]
    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Now just remove any stopwords
    stop_words = set(stopwords.words('english'))
    return [word for word in nopunc.lower().split() if word.lower() not in stopwords.words('english')]
def remove_words(word_list):
    remove = ['...','“','”','’','…']
    return [w for w in word_list if w not in remove]
# -------------------------------------------
# tokenize message column and create a column for tokens
data = data.copy() 
data['tokens'] = data['text'].apply(text_process) # tokenize style 1
data['democrats'] = data['tokens'].apply(remove_words) # tokenize style 2
data.head()
# Out:
#            created_at  favorite_count               id_str  \
# 0 2018-12-31 23:53:06          136012  1079888205351145472
# 1 2018-12-31 20:02:52           65069  1079830268708556800
# 2 2018-12-31 20:02:52           76721  1079830267274108928
# 3 2018-12-31 15:39:15          127485  1079763923845419008
# 4 2018-12-31 15:37:14          132439  1079763419908243456
#
#    in_reply_to_user_id_str  is_retweet  retweet_count              source  \
# 0                      NaN       False          33548  Twitter for iPhone
# 1               25073877.0       False          17456  Twitter for iPhone
# 2                      NaN       False          21030  Twitter for iPhone
# 3                      NaN       False          29610  Twitter for iPhone
# 4                      NaN       False          30957  Twitter for iPhone
#
#                                                 text  \
# 0                                   happy new year!
# 1  ....senator schumer, more than year longer tha...
# 2  heads countries are calling wanting know why s...
# 3  ’ incredible how democrats can all use their r...
# 4  ’ the oval office. democrats, come back from v...
#
#                                               tokens  \
# 0                                 [happy, new, year]
# 1  [senator, schumer, year, longer, administratio...
# 2  [heads, countries, calling, wanting, know, sen...
# 3  [’, incredible, democrats, use, ridiculous, so...
# 4  [’, oval, office, democrats, come, back, vacat...
#
#                                            democrats
# 0                                 [happy, new, year]
# 1  [senator, schumer, year, longer, administratio...
# 2  [heads, countries, calling, wanting, know, sen...
# 3  [incredible, democrats, use, ridiculous, sound...
# 4  [oval, office, democrats, come, back, vacation...

# %%
from wordcloud import WordCloud
from collections import Counter
# read json
data = pd.read_json('condensed_2018.json')
# split sentences to get individual words
all_words = []
for line in data['text']: # try 'tokens'
    all_words.extend(line)
    
# create a word frequency dictionary
wordfreq = Counter(data['text'])
# draw a Word Cloud with word frequencies
wordcloud = WordCloud(width=900,
                      height=500,
                      max_words=500,
                      max_font_size=100,
                      relative_scaling=0.5,
                      colormap='Blues',
                      normalize_plurals=True).generate_from_frequencies(wordfreq)
plt.figure(figsize=(17,14))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# vectorize (bag-of-words)
bow_transformer = CountVectorizer(analyzer=text_process).fit(data['text'])
# print total number of vocab words
print(len(bow_transformer.vocabulary_))
# Out:
# 10076

# %%
# example of vectorized text
sample_tweet = data['text'][111]
print(sample_tweet)
print('\n')
# Out:
# RT @realDonaldTrump: After historic victories against ISIS, it’s time to bring our great young people home! https://t.co/xoNjFzQFTp

# %%
# vector representation
bow_sample = bow_transformer.transform([sample_tweet])
print(bow_sample)
print('\n')
# Out:
#   (0, 1210)	1
#   (0, 3522)	1
#   (0, 3783)	1
#   (0, 3806)	1
#   (0, 4705)	1
#   (0, 5114)	1
#   (0, 5132)	1
#   (0, 6696)	1
#   (0, 7252)	1
#   (0, 7689)	1
#   (0, 8794)	1
#   (0, 9253)	1
#   (0, 9647)	1

# %%
# transform the entire DataFrame of text
messages_bow = bow_transformer.transform(data['text'])
# check out the bag-of-words counts for the entire corpus as a large sparse matrix
print('Shape of Sparse Matrix: ', messages_bow.shape)
print('Amount of Non-Zero occurences: ', messages_bow.nnz)
# Out:
# Shape of Sparse Matrix:  (3510, 10076)
# Amount of Non-Zero occurences:  59865

# %%
# from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer().fit(messages_bow)
tfidf_sample = tfidf_transformer.transform(bow_sample)
print(tfidf_sample)
# Out:
#   (0, 9647)	0.32262264408079255
#   (0, 9253)	0.3744214478782617
#   (0, 8794)	0.20484034916573993
#   (0, 7689)	0.15674683907790657
#   (0, 7252)	0.2059805076093194
#   (0, 6696)	0.16289869994698727
#   (0, 5132)	0.2596232093332776
#   (0, 5114)	0.31743080256672396
#   (0, 4705)	0.4183751268354609
#   (0, 3806)	0.2814737087644371
#   (0, 3783)	0.298928246723144
#   (0, 3522)	0.13011399924016492
#   (0, 1210)	0.302507260273688

# %%
# some IDF (inverse document frequency) example
print(tfidf_transformer.idf_[bow_transformer.vocabulary_['trump']])
print(tfidf_transformer.idf_[bow_transformer.vocabulary_['democrats']])
# Out:
# 3.622392631010006
# 3.5615373552887313

# %%
# to transform the entire bag-of-words corpus
messages_tfidf = tfidf_transformer.transform(messages_bow)
print(messages_tfidf.shape)
# Out:
# (3510, 10076)
